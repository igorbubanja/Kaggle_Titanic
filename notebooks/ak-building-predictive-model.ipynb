# %% [markdown]
# # Building Predictive Model - Baseline Model

# %% [markdown]
# Before we build a machine learning model, we need to build a baseline model (that uses no machine learning) do determine a baseline accuracy, which the machine learning model will need to exceed

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# ## Import Data

# %%
# set path of the processed data
processed_data_path = os.path.join(os.path.pardir, 'data', 'processed')
train_file_path = os.path.join(processed_data_path, 'train.csv')
test_file_path = os.path.join(processed_data_path, 'test.csv')

# %%
# put them into data frames
train_df = pd.read_csv(train_file_path, index_col = 'PassengerId')
test_df = pd.read_csv(test_file_path, index_col = 'PassengerId')
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ## Data Preperation

# %%
X = train_df.loc[:,'Age':].to_numpy().astype('float')

y = train_df['Survived'].ravel() # ravel creates a flattened 1 domensional array
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-3bd902ada833> in <module>
# ----> 1 X = train_df.loc[:,'Age':].to_numpy().astype('float')
#       2
#       3 #y = train_df['Survived'].ravel() # ravel creates a flattened 1 domensional array
#
# ValueError: could not convert string to float: 'A/5 21171'
